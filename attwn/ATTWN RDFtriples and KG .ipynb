# %% [markdown]
# # And Then There Were None KG

# %% [markdown]
# ## RDF Triples

# %%
import rdflib
import xlrd
import pandas
from rdflib import URIRef, Literal, BNode,Namespace

data = { # similar format for how you made your pandas data fram
    "subject": [],
    "predicate": [],
    "object" : []
}
wb = xlrd.open_workbook("ATTWN triples.xlsx")
sheet = wb.sheet_by_index(0)
for i in range(1, sheet.nrows): # skip the first header line
       
    s = sheet.cell_value(i, 0)
    p = sheet.cell_value(i, 1)
    o = sheet.cell_value(i, 2)
    
    data["subject"].append(s)
    data["predicate"].append(p)
    #print(o)
    data["object"].append(o) 
  
data_processed = {
    'subject':[],'predicate':[],'object': []
}
ugly_token = {
    ' ': '_',
    '"': '',
}
# replace all ugly tokens and copy to new data structure
for x in data.keys(): #x is subj,obj,pred
    for item in data[x]:
        if type(item)!=str:
            data_processed[x].append(item)
            continue
        new_token=item       
        for k in ugly_token:
            new_token=new_token.replace(k, ugly_token[k]) 
            
        data_processed[x].append(new_token)            

n = Namespace("http://UCLA_REU_2020.org/ATTWN/")

g = rdflib.Graph()

for i in range(len(data['subject'])):
    s = n[data_processed['subject'][i]]
    p = n[data_processed['predicate'][i]]
    o_data=data_processed['object'][i]
    if type(o_data)==float or type(o_data)==int:
        o_node=Literal(o_data)
    else:
        o_node=n[o_data]
    g.add((s, p, o_node))

#check g
for s, p, o in g:
   print((s, p, o))
# Out:
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Anthony_Martson'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_setting'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Indian_Island'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/hatchetwound'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/by_means_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/hatchet'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/because_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/religion'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/John_Macarthur'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_setting'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Indian_Island'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/William_Blore'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_lastname'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Blore'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Emily_Brent'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_firstname'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Emily'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Emily_Brent'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/came_to_island_for'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/holiday'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/William_Blore'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_body_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Lawrence_Wargrave'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/because_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/self-preservation'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/William_Blore'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/came_to_island_for'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/case'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Philip_Lombard'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_body_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/William_Blore'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Anthony_Martson'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_lastname'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Marston'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/is_character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Ethel_Rogers'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Vera_Claythorne'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_body_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Anthony_Marston'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Philip_Lombard'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/committed_'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Philip_Lombard'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/escaped_conviction_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Lawrence_Wargrave'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_lastname'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Wargrave'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Thomas_Rogers'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/heard_clue'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/record'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Lawrence_Wargrave'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/escaped_conviction_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Vera_Claythorne'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_firstname'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Vera'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Emily_Brent'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/injection'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_time'), rdflib.term.Literal('9.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/John_Macarthur'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed_'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/because_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/justice'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Vera_Claythorne'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/came_to_island_for'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/secretarial_position'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Vera_Claythorne'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Lawrence_Wargrave'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_body_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Anthony_Marston'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Third_Soldier'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/death_by'), rdflib.term.URIRef("http://UCLA_REU_2020.org/ATTWN/he'd_stay_there"))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Lawrence_Wargrave'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/invited_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Constance_Culmington'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/William_Blore'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_body_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Anthony_Marston'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/William_Blore'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/John_Macarthur'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_clue'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/poem'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/is_character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Vera_Claythorne'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/injection'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/by_means_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/syringe'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Poem'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_title'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Ten_Little_Soldiers'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_time'), rdflib.term.Literal('-10.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Ethel_Rogers'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/committed_'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Edward_Armstrong'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/is_character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Thomas_Rogers'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Thomas_Rogers'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/married_to'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Ethel_Rogers'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Ethel_Rogers'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/escaped_conviction_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/patient'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/is_character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Anthony_Marston'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/William_Blore'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_firstname'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/William'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Vera_Claythorne'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/heard_clue'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/record'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Ethel_Rogers'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_firstname'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Ethel'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Tenth_Soldier'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/character_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/poem'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/First_Soldier'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/character_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Poem'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Emily_Brent'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_lastname'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Brent'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Ninth_Soldier'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/character_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/poem'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Gun'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/owned_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Philip_Lombard'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Fourth_Soldier'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/death_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/chopped_in_halves'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Edward_Armstrong'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_setting'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Indian_Island'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/gunshot'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Thomas_Rogers'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/committed_'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Thomas_Rogers'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_lastname'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Rogers'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Edward_Armstrong'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/heard_clue'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/record'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/John_Macarthur'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/came_to_island_for'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/reunion'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Bear-shaped_clock'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/owned_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Vera_Claythorne'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Lawrence_Wargrave'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_profession'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/retired_judge'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Tenth_Soldier'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/death_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/hanging'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Edward_Armstrong'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/invited_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Mr.Owen'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Lawrence_Wargrave'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/committed_'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Philip_Lombard'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_body_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Edward_Armstrong'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Ninth_Solider'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/death_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/frizzled_up'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/because_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/inheritance'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/William_Blore'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_profession_'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/former_detective'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Philip_Lombard'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_body_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Emily_Brent'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Thomas_Rogers'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed_'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Philip_Lombard'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed_'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/is_character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Emily_Brent'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Record'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/is_named'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Swan_Song'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Edward_Armstrong'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_body_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Ethel_Rogers'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/William_Blore'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_setting'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Indian_Island'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/choking'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Philip_Lombard'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_firstname'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Philip'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_time'), rdflib.term.Literal('6.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Philip_Lombard'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/came_to_island_for'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/job'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Ethel_Rogers'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/married_to'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Thomas_Rogers'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Sixth_Soldier'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/death_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/got_in_chancery'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Eighth_Soldier'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/death_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/big_bear_hugged_one'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Anthony_Martson'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_firstname'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Anthony'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Ethel_Rogers'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_body_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Anthony_Marston'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Vera_Claythorne'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_clue'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/poem'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Edward_Armstrong'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_body_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Lawrence_Wargrave'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/William_Blore'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_body_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Emily_Brent'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/is_character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Edward_Armstrong'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_time'), rdflib.term.Literal('7.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Thomas_Rogers'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/escaped_conviction_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/drowning'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/by_means_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/shove'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/gunshot'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/by_means_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/gun'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Second_Soldier'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/character_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Poem'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Fifth_Soldier'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/death_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/bee_sting'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Lawrence_Wargrave'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed_'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Edward_Armstrong'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_profession'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/doctor'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_time'), rdflib.term.Literal('3.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Edward_Armstrong'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/came_to_island_for'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/check-up'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Ethel_Rogers'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/heard_clue'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/record'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Lawrence_Wargrave'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/heard_clue'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/record'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/William_Blore'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_clue'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/poem'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Anthony_Martson'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Edward_Armstrong'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/committed_'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed_'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/suspect'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/John_Macarthur'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed_'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/defendant'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed_'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/boy'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Emily_Brent'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_clue'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/poem'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Edward_Armstrong'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/escaped_conviction_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/hanging'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/by_means_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/noose'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/because_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/corruptness'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Ethel_Rogers'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_profession'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/housekeeper'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Philip_Lombard'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_setting'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Indian_Island'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_time'), rdflib.term.Literal('4.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Pills'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/given_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Edward_Armstrong'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Blow_to_head'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/by_means_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/rock'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Emily_Brent'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/committed_'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Edward_Armstrong'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_lastname'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Armstrong'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/William_Blore'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/heard_clue'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/record'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Vera_Claythorne'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_body_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Thomas_Rogers'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/sleep'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/by_means_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/pills'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Eighth_Soldier'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/character_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/poem'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/sleep'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/twentyone_people'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/John_Macarthur'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_body_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Anthony_Marston'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Philip_Lombard'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_body_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Lawrence_Armstrong'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Emily_Brent'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/invited_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/forgotten_acquaintance'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/because_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/jealousy'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Thomas_Rogers'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_body_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Ethel_Rogers'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/because_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/alcoholism'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Anthony_Martson'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/heard_clue'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/record'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Lawrence_Wargrave'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_firstname'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Lawrence'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_time'), rdflib.term.Literal('5.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Anthony_Martson'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/committed_'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed_'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/21_people'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Emily_Brent'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_setting'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Indian_Island'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Seventh_Soldier'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/character_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/poem'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Fifth_Soldier'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/character_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/poem'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Vera_Claythorne'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_body_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/William_Blore'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Edward_Armstrong'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_firstname'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Edward_'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Lawrence_Wargrave'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/came_to_island_for'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/friend'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Ethel_Rogers'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Philip_Lombard'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_body_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Anthony_Marston'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Record'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/describes'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Vera_Claythorne'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/committed_'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Edward_Armstrong'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_clue'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/poem'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Vera_Claythorne'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/escaped_conviction_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Vera_Claythorne'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/invited_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Una_Nancy_Owen'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Edward_Armstrong'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_body_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Emily_Brent'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/is_character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/William_Blore'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Thomas_Rogers'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_profession'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/butler'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Edward_Armstrong'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed_'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Philip_Lombard'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Edward_Armstrong'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_body_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/John_Macarthur'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/William_Blore'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/committed_'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed_'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/patient'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_time'), rdflib.term.Literal('10.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/is_character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Philip_Lombard'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/choking'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/by_means_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/poison'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Ethel_Rogers'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_clue'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/poem'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Emily_Brent'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed_'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Anthony_Martson'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/escaped_conviction_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/John_Macarthur'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/escaped_conviction_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/suspect'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/crushed'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/John_Macarthur'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/committed_'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Vera_Claythorne'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_body_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Lawrence_Wargrave'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/hanging'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Ethel_Rogers'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_lastname'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Rogers'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/First_Soldier'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/death_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/choking'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Emily_Brent'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/heard_clue'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/record'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Philip_Lombard'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/heard_clue'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/record'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/William_Blore'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed_'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Syringe'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/owned_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Edward_Armstrong'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_time'), rdflib.term.Literal('2.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Emily_Brent'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/escaped_conviction_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed_'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/maid'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/John_Macarthur'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_firstname'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/John'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed_'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/two_children'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed_'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/employer'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_time'), rdflib.term.Literal('8.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/crushed'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/by_means_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/bear_shaped_clock'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Thomas_Rogers'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_body_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Anthony_Marston'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Thomas_Rogers'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/because_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/money'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Blow_to_head'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/William_Blore'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/escaped_conviction_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Lawrence_Wargrave'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_setting'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Indian_Island'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Vera_Claythorne'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_body_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Edward_Armstrong'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/John_Macarthur'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/heard_clue'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/record'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Vera_Claythorne'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_profession'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/former_governess'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Edward_Armstrong'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_body_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Anthony_Marston'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Vera_Claythorne'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_body_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Emily_Brent'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Thomas_Rogers'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_clue'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/poem'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Vera_Claythorne'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed_'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Lawrence_Wargrave'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Second_Soldier'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/death_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/overslept'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed_'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/lieutenant_'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/lieutenant'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Anthony_Martson'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed_'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Seventh_Soldier'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/death_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/red_herring_swallowed_one'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Philip_Lombard'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/invited_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Isaac_Morris'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Philip_Lombard'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_clue'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/poem'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Philip_Lombard_'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_profession'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/veteran'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/drowning'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Anthony_Martson'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_clue'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/poem'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/hatchetwound'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Ethel_Rogers'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed_'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Fourth_Soldier'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/character_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/poem'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Lawrence_Wargrave'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_body_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Emily_Brent'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/maid'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/two_children'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/defendant'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Vera_Claythorne'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_lastname'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Claythorne'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/John_Macarthur'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_lastname'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Macarthur'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Thomas_Rogers'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_firstname'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Thomas'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Sixth_Soldier'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/character_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/poem'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/because_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/reckless_driving'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Emily_Brent'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_body_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Anthony_Marston'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Third_Soldier'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/character_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/poem'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/is_character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/John_Macarthur_'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/John_Macarthur'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_profession'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Army_General'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/boy'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Vera_Claythorne'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_setting'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Indian_Island'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/employer'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_time'), rdflib.term.Literal('1.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Philip_Lombard'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_lastname'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Lombard'))

# %% [markdown]
# ## visualization

# %%
import matplotlib.pyplot as plt
import networkx as nx
# %matplotlib qt
#%matplotlib inline
plt.figure(figsize=(20,20))

edgelabels={}
G = nx.DiGraph()
#plt.clf()
for i in range(len(data['object'])):
    v1 = data['subject'][i]
    v2 = data['object'][i]
    G.add_edge(v1,v2)
    e_lbl = data['predicate'][i]
    edgelabels[(v1, v2)] = e_lbl

#print(edge_labels)

pos = nx.spring_layout(G,k=0.15,iterations=20, scale=3)
nx.draw_networkx(G, pos=pos,font_size=8,node_color='pink')
nx.draw_networkx_edge_labels(G, pos=pos, edge_labels=edgelabels, font_size=7)

plt.show()
# Out:
# C:\Users\masha\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:563: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# C:\Users\masha\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:660: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes

# %%
   from SPARQLWrapper import SPARQLWrapper, JSON

sparql = SPARQLWrapper("http://dbpedia.org/sparql")
sparql.setQuery("""
    PREFIX xml: <http://www.w3.org/XML/1998/namespace>
    SELECT ?first_name
    WHERE { <http://www.semanticweb.org/carol/ontologies/2020/6/attwn_ontology> xml:first_name ?first_name}
""")
sparql.setReturnFormat(JSON)
results = sparql.query().convert()
print(results)
for result in results["results"]["bindings"]:
    print(result["label"]["value"])
# Out:
# {'head': {'link': [], 'vars': ['first_name']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}

# %%
qres = g.query(
    """SELECT ?subject ?predicate ?object
WHERE {?subject ?predicate ?object} 

       """)

for row in qres:
    print(row)
# Out:
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Anthony_Martson'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_setting'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Indian_Island'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/hatchetwound'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/by_means_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/hatchet'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/because_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/religion'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/John_Macarthur'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_setting'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Indian_Island'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/William_Blore'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_lastname'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Blore'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Emily_Brent'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_firstname'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Emily'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Emily_Brent'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/came_to_island_for'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/holiday'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/William_Blore'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_body_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Lawrence_Wargrave'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/because_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/self-preservation'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/William_Blore'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/came_to_island_for'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/case'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Philip_Lombard'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_body_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/William_Blore'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Anthony_Martson'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_lastname'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Marston'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/is_character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Ethel_Rogers'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Vera_Claythorne'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_body_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Anthony_Marston'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Philip_Lombard'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/committed_'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Philip_Lombard'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/escaped_conviction_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Lawrence_Wargrave'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_lastname'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Wargrave'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Thomas_Rogers'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/heard_clue'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/record'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Lawrence_Wargrave'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/escaped_conviction_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Vera_Claythorne'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_firstname'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Vera'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Emily_Brent'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/injection'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_time'), rdflib.term.Literal('9.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/John_Macarthur'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed_'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/because_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/justice'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Vera_Claythorne'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/came_to_island_for'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/secretarial_position'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Vera_Claythorne'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Lawrence_Wargrave'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_body_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Anthony_Marston'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Third_Soldier'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/death_by'), rdflib.term.URIRef("http://UCLA_REU_2020.org/ATTWN/he'd_stay_there"))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Lawrence_Wargrave'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/invited_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Constance_Culmington'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/William_Blore'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_body_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Anthony_Marston'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/William_Blore'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/John_Macarthur'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_clue'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/poem'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/is_character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Vera_Claythorne'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/injection'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/by_means_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/syringe'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Poem'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_title'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Ten_Little_Soldiers'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_time'), rdflib.term.Literal('-10.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Ethel_Rogers'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/committed_'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Edward_Armstrong'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/is_character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Thomas_Rogers'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Thomas_Rogers'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/married_to'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Ethel_Rogers'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Ethel_Rogers'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/escaped_conviction_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/patient'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/is_character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Anthony_Marston'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/William_Blore'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_firstname'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/William'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Vera_Claythorne'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/heard_clue'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/record'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Ethel_Rogers'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_firstname'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Ethel'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Tenth_Soldier'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/character_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/poem'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/First_Soldier'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/character_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Poem'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Emily_Brent'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_lastname'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Brent'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Ninth_Soldier'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/character_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/poem'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Gun'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/owned_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Philip_Lombard'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Fourth_Soldier'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/death_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/chopped_in_halves'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Edward_Armstrong'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_setting'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Indian_Island'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/gunshot'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Thomas_Rogers'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/committed_'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Thomas_Rogers'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_lastname'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Rogers'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Edward_Armstrong'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/heard_clue'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/record'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/John_Macarthur'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/came_to_island_for'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/reunion'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Bear-shaped_clock'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/owned_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Vera_Claythorne'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Lawrence_Wargrave'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_profession'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/retired_judge'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Tenth_Soldier'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/death_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/hanging'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Edward_Armstrong'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/invited_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Mr.Owen'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Lawrence_Wargrave'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/committed_'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Philip_Lombard'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_body_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Edward_Armstrong'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Ninth_Solider'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/death_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/frizzled_up'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/because_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/inheritance'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/William_Blore'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_profession_'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/former_detective'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Philip_Lombard'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_body_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Emily_Brent'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Thomas_Rogers'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed_'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Philip_Lombard'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed_'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/is_character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Emily_Brent'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Record'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/is_named'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Swan_Song'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Edward_Armstrong'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_body_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Ethel_Rogers'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/William_Blore'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_setting'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Indian_Island'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/choking'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Philip_Lombard'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_firstname'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Philip'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_time'), rdflib.term.Literal('6.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Philip_Lombard'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/came_to_island_for'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/job'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Ethel_Rogers'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/married_to'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Thomas_Rogers'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Sixth_Soldier'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/death_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/got_in_chancery'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Eighth_Soldier'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/death_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/big_bear_hugged_one'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Anthony_Martson'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_firstname'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Anthony'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Ethel_Rogers'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_body_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Anthony_Marston'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Vera_Claythorne'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_clue'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/poem'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Edward_Armstrong'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_body_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Lawrence_Wargrave'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/William_Blore'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_body_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Emily_Brent'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/is_character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Edward_Armstrong'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_time'), rdflib.term.Literal('7.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Thomas_Rogers'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/escaped_conviction_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/drowning'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/by_means_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/shove'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/gunshot'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/by_means_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/gun'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Second_Soldier'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/character_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Poem'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Fifth_Soldier'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/death_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/bee_sting'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Lawrence_Wargrave'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed_'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Edward_Armstrong'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_profession'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/doctor'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_time'), rdflib.term.Literal('3.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Edward_Armstrong'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/came_to_island_for'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/check-up'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Ethel_Rogers'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/heard_clue'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/record'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Lawrence_Wargrave'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/heard_clue'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/record'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/William_Blore'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_clue'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/poem'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Anthony_Martson'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Edward_Armstrong'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/committed_'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed_'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/suspect'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/John_Macarthur'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed_'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/defendant'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed_'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/boy'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Emily_Brent'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_clue'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/poem'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Edward_Armstrong'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/escaped_conviction_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/hanging'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/by_means_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/noose'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/because_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/corruptness'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Ethel_Rogers'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_profession'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/housekeeper'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Philip_Lombard'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_setting'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Indian_Island'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_time'), rdflib.term.Literal('4.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Pills'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/given_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Edward_Armstrong'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Blow_to_head'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/by_means_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/rock'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Emily_Brent'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/committed_'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Edward_Armstrong'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_lastname'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Armstrong'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/William_Blore'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/heard_clue'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/record'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Vera_Claythorne'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_body_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Thomas_Rogers'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/sleep'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/by_means_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/pills'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Eighth_Soldier'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/character_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/poem'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/sleep'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/twentyone_people'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/John_Macarthur'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_body_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Anthony_Marston'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Philip_Lombard'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_body_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Lawrence_Armstrong'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Emily_Brent'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/invited_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/forgotten_acquaintance'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/because_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/jealousy'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Thomas_Rogers'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_body_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Ethel_Rogers'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/because_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/alcoholism'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Anthony_Martson'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/heard_clue'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/record'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Lawrence_Wargrave'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_firstname'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Lawrence'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_time'), rdflib.term.Literal('5.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Anthony_Martson'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/committed_'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed_'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/21_people'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Emily_Brent'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_setting'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Indian_Island'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Seventh_Soldier'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/character_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/poem'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Fifth_Soldier'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/character_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/poem'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Vera_Claythorne'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_body_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/William_Blore'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Edward_Armstrong'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_firstname'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Edward_'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Lawrence_Wargrave'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/came_to_island_for'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/friend'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Ethel_Rogers'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Philip_Lombard'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_body_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Anthony_Marston'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Record'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/describes'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Vera_Claythorne'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/committed_'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Edward_Armstrong'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_clue'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/poem'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Vera_Claythorne'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/escaped_conviction_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Vera_Claythorne'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/invited_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Una_Nancy_Owen'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Edward_Armstrong'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_body_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Emily_Brent'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/is_character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/William_Blore'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Thomas_Rogers'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_profession'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/butler'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Edward_Armstrong'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed_'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Philip_Lombard'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Edward_Armstrong'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_body_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/John_Macarthur'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/William_Blore'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/committed_'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed_'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/patient'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_time'), rdflib.term.Literal('10.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/is_character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Philip_Lombard'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/choking'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/by_means_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/poison'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Ethel_Rogers'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_clue'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/poem'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Emily_Brent'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed_'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Anthony_Martson'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/escaped_conviction_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/John_Macarthur'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/escaped_conviction_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/suspect'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/crushed'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/John_Macarthur'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/committed_'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Vera_Claythorne'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_body_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Lawrence_Wargrave'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/hanging'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Ethel_Rogers'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_lastname'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Rogers'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/First_Soldier'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/death_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/choking'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Emily_Brent'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/heard_clue'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/record'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Philip_Lombard'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/heard_clue'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/record'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/William_Blore'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed_'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Syringe'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/owned_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Edward_Armstrong'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_time'), rdflib.term.Literal('2.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Emily_Brent'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/escaped_conviction_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed_'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/maid'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/John_Macarthur'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_firstname'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/John'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed_'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/two_children'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed_'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/employer'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_time'), rdflib.term.Literal('8.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/crushed'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/by_means_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/bear_shaped_clock'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Thomas_Rogers'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_body_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Anthony_Marston'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Thomas_Rogers'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/because_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/money'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Blow_to_head'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/William_Blore'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/escaped_conviction_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Lawrence_Wargrave'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_setting'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Indian_Island'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Vera_Claythorne'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_body_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Edward_Armstrong'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/John_Macarthur'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/heard_clue'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/record'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Vera_Claythorne'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_profession'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/former_governess'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Edward_Armstrong'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_body_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Anthony_Marston'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Vera_Claythorne'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_body_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Emily_Brent'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Thomas_Rogers'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_clue'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/poem'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Vera_Claythorne'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed_'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Lawrence_Wargrave'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Second_Soldier'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/death_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/overslept'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed_'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/lieutenant_'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/lieutenant'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Anthony_Martson'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed_'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Seventh_Soldier'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/death_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/red_herring_swallowed_one'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Philip_Lombard'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/invited_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Isaac_Morris'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Philip_Lombard'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_clue'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/poem'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Philip_Lombard_'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_profession'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/veteran'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/drowning'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Anthony_Martson'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_clue'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/poem'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/hatchetwound'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Ethel_Rogers'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed_'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Fourth_Soldier'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/character_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/poem'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Lawrence_Wargrave'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_body_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Emily_Brent'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/maid'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/two_children'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/defendant'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Vera_Claythorne'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_lastname'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Claythorne'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/John_Macarthur'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_lastname'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Macarthur'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Thomas_Rogers'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_firstname'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Thomas'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Sixth_Soldier'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/character_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/poem'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/past_crime'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/because_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/reckless_driving'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Emily_Brent'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/found_body_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Anthony_Marston'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Third_Soldier'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/character_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/poem'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/is_character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/John_Macarthur_'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/John_Macarthur'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_profession'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Army_General'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/boy'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Vera_Claythorne'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_setting'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Indian_Island'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/employer'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_predicate'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/had_killed'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/died_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_time'), rdflib.term.Literal('1.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Philip_Lombard'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/has_lastname'), rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Lombard'))

# %%
qres = g.query(
    """SELECT ?first_name
WHERE {?first_name} 

       """)

for row in qres:
    print(row)
# Out:
# ---------------------------------------------------------------------------
# ParseException                            Traceback (most recent call last)
# <ipython-input-7-ceb794cc9e68> in <module>
#       3 WHERE {?first_name}
#       4
# ----> 5        """)
#       6
#       7 for row in qres:
#
# ~\Anaconda3\lib\site-packages\rdflib\graph.py in query(self, query_object, processor, result, initNs, initBindings, use_store_provided, **kwargs)
#    1129             processor = plugin.get(processor, query.Processor)(self)
#    1130
# -> 1131         return result(processor.query(query_object, initBindings, initNs, **kwargs))
#    1132
#    1133     def update(
#
# ~\Anaconda3\lib\site-packages\rdflib\plugins\sparql\processor.py in query(self, strOrQuery, initBindings, initNs, base, DEBUG)
#      74
#      75         if not isinstance(strOrQuery, Query):
# ---> 76             parsetree = parseQuery(strOrQuery)
#      77             query = translateQuery(parsetree, base, initNs)
#      78         else:
#
# ~\Anaconda3\lib\site-packages\rdflib\plugins\sparql\parser.py in parseQuery(q)
#    1058
#    1059     q = expandUnicodeEscapes(q)
# -> 1060     return Query.parseString(q, parseAll=True)
#    1061
#    1062
#
# ~\Anaconda3\lib\site-packages\pyparsing.py in parseString(self, instring, parseAll)
#    1674             else:
#    1675                 # catch and re-raise exception from here, clears out pyparsing internal stack trace
# -> 1676                 raise exc
#    1677         else:
#    1678             return tokens
#
# ~\Anaconda3\lib\site-packages\pyparsing.py in parseString(self, instring, parseAll)
#    1664             instring = instring.expandtabs()
#    1665         try:
# -> 1666             loc, tokens = self._parse( instring, 0 )
#    1667             if parseAll:
#    1668                 loc = self.preParse( instring, loc )
#
# ~\Anaconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1410             if self.mayIndexError or preloc >= len(instring):
#    1411                 try:
# -> 1412                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1413                 except IndexError:
#    1414                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# ~\Anaconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    3481                     raise ParseSyntaxException(instring, len(instring), self.errmsg, self)
#    3482             else:
# -> 3483                 loc, exprtokens = e._parse( instring, loc, doActions )
#    3484             if exprtokens or exprtokens.haskeys():
#    3485                 resultlist += exprtokens
#
# ~\Anaconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1410             if self.mayIndexError or preloc >= len(instring):
#    1411                 try:
# -> 1412                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1413                 except IndexError:
#    1414                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# ~\Anaconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    3631             if maxException is not None:
#    3632                 maxException.msg = self.errmsg
# -> 3633                 raise maxException
#    3634             else:
#    3635                 raise ParseException(instring, loc, "no defined alternatives to match", self)
#
# ~\Anaconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    3616         for e in self.exprs:
#    3617             try:
# -> 3618                 ret = e._parse( instring, loc, doActions )
#    3619                 return ret
#    3620             except ParseException as err:
#
# ~\Anaconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1410             if self.mayIndexError or preloc >= len(instring):
#    1411                 try:
# -> 1412                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1413                 except IndexError:
#    1414                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# ~\Anaconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    3803     def parseImpl( self, instring, loc, doActions=True ):
#    3804         if self.expr is not None:
# -> 3805             return self.expr._parse( instring, loc, doActions, callPreParse=False )
#    3806         else:
#    3807             raise ParseException("",loc,self.errmsg,self)
#
# ~\Anaconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1410             if self.mayIndexError or preloc >= len(instring):
#    1411                 try:
# -> 1412                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1413                 except IndexError:
#    1414                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# ~\Anaconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    3481                     raise ParseSyntaxException(instring, len(instring), self.errmsg, self)
#    3482             else:
# -> 3483                 loc, exprtokens = e._parse( instring, loc, doActions )
#    3484             if exprtokens or exprtokens.haskeys():
#    3485                 resultlist += exprtokens
#
# ~\Anaconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1410             if self.mayIndexError or preloc >= len(instring):
#    1411                 try:
# -> 1412                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1413                 except IndexError:
#    1414                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# ~\Anaconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    3803     def parseImpl( self, instring, loc, doActions=True ):
#    3804         if self.expr is not None:
# -> 3805             return self.expr._parse( instring, loc, doActions, callPreParse=False )
#    3806         else:
#    3807             raise ParseException("",loc,self.errmsg,self)
#
# ~\Anaconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1410             if self.mayIndexError or preloc >= len(instring):
#    1411                 try:
# -> 1412                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1413                 except IndexError:
#    1414                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# ~\Anaconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    3803     def parseImpl( self, instring, loc, doActions=True ):
#    3804         if self.expr is not None:
# -> 3805             return self.expr._parse( instring, loc, doActions, callPreParse=False )
#    3806         else:
#    3807             raise ParseException("",loc,self.errmsg,self)
#
# ~\Anaconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1410             if self.mayIndexError or preloc >= len(instring):
#    1411                 try:
# -> 1412                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1413                 except IndexError:
#    1414                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# ~\Anaconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    3481                     raise ParseSyntaxException(instring, len(instring), self.errmsg, self)
#    3482             else:
# -> 3483                 loc, exprtokens = e._parse( instring, loc, doActions )
#    3484             if exprtokens or exprtokens.haskeys():
#    3485                 resultlist += exprtokens
#
# ~\Anaconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1414                     raise ParseException( instring, len(instring), self.errmsg, self )
#    1415             else:
# -> 1416                 loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1417
#    1418         tokens = self.postParse( instring, loc, tokens )
#
# ~\Anaconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    3803     def parseImpl( self, instring, loc, doActions=True ):
#    3804         if self.expr is not None:
# -> 3805             return self.expr._parse( instring, loc, doActions, callPreParse=False )
#    3806         else:
#    3807             raise ParseException("",loc,self.errmsg,self)
#
# ~\Anaconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1414                     raise ParseException( instring, len(instring), self.errmsg, self )
#    1415             else:
# -> 1416                 loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1417
#    1418         tokens = self.postParse( instring, loc, tokens )
#
# ~\Anaconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    2455             (self.matchLen==1 or instring.startswith(self.match,loc)) ):
#    2456             return loc+self.matchLen, self.match
# -> 2457         raise ParseException(instring, loc, self.errmsg, self)
#    2458 _L = Literal
#    2459 ParserElement._literalStringClass = Literal
#
# ParseException: Expected {SelectQuery | ConstructQuery | DescribeQuery | AskQuery} (at char 26), (line:2, col:8)

# %%
qres = g.query(
    """
       PREFIX xml: <"http://UCLA_REU_2020.org/ATTWN/">
       SELECT DISTINCT ?obj
       WHERE {
          xml:first_name ?pred ?obj
       }""")
# Out:
# ---------------------------------------------------------------------------
# ParseException                            Traceback (most recent call last)
# <ipython-input-11-bbb65a4166f0> in <module>
#       5        WHERE {
#       6           xml:first_name ?pred ?obj
# ----> 7        }""")
#
# ~\Anaconda3\lib\site-packages\rdflib\graph.py in query(self, query_object, processor, result, initNs, initBindings, use_store_provided, **kwargs)
#    1129             processor = plugin.get(processor, query.Processor)(self)
#    1130
# -> 1131         return result(processor.query(query_object, initBindings, initNs, **kwargs))
#    1132
#    1133     def update(
#
# ~\Anaconda3\lib\site-packages\rdflib\plugins\sparql\processor.py in query(self, strOrQuery, initBindings, initNs, base, DEBUG)
#      74
#      75         if not isinstance(strOrQuery, Query):
# ---> 76             parsetree = parseQuery(strOrQuery)
#      77             query = translateQuery(parsetree, base, initNs)
#      78         else:
#
# ~\Anaconda3\lib\site-packages\rdflib\plugins\sparql\parser.py in parseQuery(q)
#    1058
#    1059     q = expandUnicodeEscapes(q)
# -> 1060     return Query.parseString(q, parseAll=True)
#    1061
#    1062
#
# ~\Anaconda3\lib\site-packages\pyparsing.py in parseString(self, instring, parseAll)
#    1674             else:
#    1675                 # catch and re-raise exception from here, clears out pyparsing internal stack trace
# -> 1676                 raise exc
#    1677         else:
#    1678             return tokens
#
# ~\Anaconda3\lib\site-packages\pyparsing.py in parseString(self, instring, parseAll)
#    1664             instring = instring.expandtabs()
#    1665         try:
# -> 1666             loc, tokens = self._parse( instring, 0 )
#    1667             if parseAll:
#    1668                 loc = self.preParse( instring, loc )
#
# ~\Anaconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1410             if self.mayIndexError or preloc >= len(instring):
#    1411                 try:
# -> 1412                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1413                 except IndexError:
#    1414                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# ~\Anaconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    3481                     raise ParseSyntaxException(instring, len(instring), self.errmsg, self)
#    3482             else:
# -> 3483                 loc, exprtokens = e._parse( instring, loc, doActions )
#    3484             if exprtokens or exprtokens.haskeys():
#    3485                 resultlist += exprtokens
#
# ~\Anaconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1410             if self.mayIndexError or preloc >= len(instring):
#    1411                 try:
# -> 1412                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1413                 except IndexError:
#    1414                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# ~\Anaconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    3631             if maxException is not None:
#    3632                 maxException.msg = self.errmsg
# -> 3633                 raise maxException
#    3634             else:
#    3635                 raise ParseException(instring, loc, "no defined alternatives to match", self)
#
# ~\Anaconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    3616         for e in self.exprs:
#    3617             try:
# -> 3618                 ret = e._parse( instring, loc, doActions )
#    3619                 return ret
#    3620             except ParseException as err:
#
# ~\Anaconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1410             if self.mayIndexError or preloc >= len(instring):
#    1411                 try:
# -> 1412                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1413                 except IndexError:
#    1414                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# ~\Anaconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    3803     def parseImpl( self, instring, loc, doActions=True ):
#    3804         if self.expr is not None:
# -> 3805             return self.expr._parse( instring, loc, doActions, callPreParse=False )
#    3806         else:
#    3807             raise ParseException("",loc,self.errmsg,self)
#
# ~\Anaconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1410             if self.mayIndexError or preloc >= len(instring):
#    1411                 try:
# -> 1412                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1413                 except IndexError:
#    1414                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# ~\Anaconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    3464         # pass False as last arg to _parse for first element, since we already
#    3465         # pre-parsed the string as part of our And pre-parsing
# -> 3466         loc, resultlist = self.exprs[0]._parse( instring, loc, doActions, callPreParse=False )
#    3467         errorStop = False
#    3468         for e in self.exprs[1:]:
#
# ~\Anaconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1414                     raise ParseException( instring, len(instring), self.errmsg, self )
#    1415             else:
# -> 1416                 loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1417
#    1418         tokens = self.postParse( instring, loc, tokens )
#
# ~\Anaconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    2563              (loc >= len(instring)-self.matchLen or instring[loc+self.matchLen].upper() not in self.identChars) ):
#    2564             return loc+self.matchLen, self.match
# -> 2565         raise ParseException(instring, loc, self.errmsg, self)
#    2566
#    2567 class CloseMatch(Token):
#
# ParseException: Expected {SelectQuery | ConstructQuery | DescribeQuery | AskQuery} (at char 8), (line:2, col:8)

# %%
qres = g.query(
    """PREFIX foaf: <http://UCLA_REU_2020.org/ATTWN/>
       SELECT ?bname
       WHERE {
          # ?aname foaf:has_firstname ?bname.
       }""")

for row in qres:
    print(row)
# Out:
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Anthony'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Philip'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/John'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Edward_'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Emily'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Thomas'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/William'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Ethel'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Lawrence'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Vera'),)

# %%
qres = g.query(
    """PREFIX foaf: <http://UCLA_REU_2020.org/ATTWN/>
       SELECT ?bname
       WHERE {
          # ?aname foaf:has_profession ?bname.
       }""")

for row in qres:
    print(row)
# Out:
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/doctor'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/butler'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/retired_judge'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/veteran'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Army_General'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/housekeeper'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/former_governess'),)

# %%
qres = g.query(
    """PREFIX foaf: <http://UCLA_REU_2020.org/ATTWN/>
       SELECT ?bname
       WHERE {
          # ?aname foaf:has_lastname ?bname.
       }""")

for row in qres:
    print(row)
# Out:
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Blore'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Marston'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Rogers'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Claythorne'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Macarthur'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Wargrave'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Rogers'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Brent'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Lombard'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/ATTWN/Armstrong'),)
