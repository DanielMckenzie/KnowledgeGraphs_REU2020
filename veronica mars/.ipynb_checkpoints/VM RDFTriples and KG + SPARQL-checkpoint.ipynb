# %% [markdown]
# # Veronica Mars Knowledge Graph

# %% [markdown]
# ## RDF Triples

# %%
'''
    Create the RDF Triples w/o time or reification
    This Version includes ontology-based refinement at creation time of the knowledge graph
'''
import rdflib
import xlrd
import pandas
from rdflib import URIRef, Literal, BNode,Namespace

data = { # similar format for how you made your pandas data fram
    "subject": [],
    "predicate": [],
    "object" : [],
}
SS_name = "VMars Triples.xlsx"
wb = xlrd.open_workbook(SS_name)

for l in range(wb.nsheets):
    sheet = wb.sheet_by_index(l)
    for i in range(1, sheet.nrows): # skip the first header line
        s = sheet.cell_value(i, 0)
        p = sheet.cell_value(i, 1)
        o = sheet.cell_value(i, 2)

        if not s or not p or not o: # if any are empty then no triple
            continue
            
        data["subject"].append(s)
        data["predicate"].append(p)
        data["object"].append(o)

    
data_processed = {
    'subject':[],'predicate':[],'object': []
}
ugly_token = {
    ' ': '_',
    '"': '',
}

# replace all ugly tokens and copy to new data structure
for x in data.keys(): #x is subj,obj,pred
    for item in data[x]:
        if type(item)!=str:
            data_processed[x].append(item)
            continue
        new_token=item       
        for k in ugly_token:
            new_token = new_token.strip()
            new_token=new_token.replace(k, ugly_token[k]) 
            
        data_processed[x].append(new_token)            

n = Namespace("http://UCLA_REU_2020.org/Veronica_Mars/")

g = rdflib.Graph()
pred_counts = {} # Dictionary mapping each predicate to the number of times they have been used

for i in range(len(data['subject'])):
    s = n[data_processed['subject'][i]]
    p = n[data_processed['predicate'][i]]
    o_data=data_processed['object'][i]
    if type(o_data)==float or type(o_data)==int:
        o_node=Literal(o_data)
    else:
        o_node=n[o_data]
    g.add((s, p, o_node))

    
'''
    Refinement:
        Reference to symmetrics and inverses in VM Predicates Google Sheet
    Here we list the symmetric predicates and the predicates with well-defined inverses.
    Then if one side of the symmetry or inverse is missing, we add it to the knowledge graph.
'''
symmetric_preds = [
    'bestfriend_of', 'sibling_of', 'friend_of', 'ex_of', 
    'ex_friend_of', 'married_to', 'has_affair_with'
]
inverse_pred = {
    'girlfriend_of': 'boyfriend_of'
}
# (x^-1)^-1 = x --> this line adds inverses of each explicit entry 
inverse_pred.update({inverse_pred[k]: k for k in inverse_pred})

num_added_triples = 0
added_triples = []

for pred in symmetric_preds:
    existing_t = g.triples((None, n[pred], None))
    for t in existing_t:
        inverse = t[::-1]
        if inverse not in g:
            num_added_triples += 1
            added_triples.append(list(map(lambda x: stripURI(x), inverse)))
            g.add(inverse)
for pred in inverse_pred:
    existing_t = g.triples((None, n[pred], None))
    for t in existing_t:
        inverse = (t[2], n[inverse_pred[pred]], t[0])
        if inverse not in g:
            num_added_triples += 1
            added_triples.append(list(map(lambda x: stripURI(x), inverse)))
            g.add(inverse)
print('triples added: {}'.format(num_added_triples))
#check g
for s, p, o in g:
   print((s, p, o))
# Out:
# triples added: 35
# (rdflib.term.URIRef("http://UCLA_REU_2020.org/Veronica_Mars/Sarah's_DNA_Test"), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/consists_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/paternity'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/is_character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Hamilton_Cho'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Lilly_Kane'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/part_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/pep_squad'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Carrie_Bishop'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/accused'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Chuck_Rook'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Jerry_Sacks'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_last_name'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Sacks'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Ben'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/suspect_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case18'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Nathan'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_profession'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/retail_associate'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Trina_Echolls'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_profession'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/actress'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Holly_Mills'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_last_name'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Mills'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Caitlin_Ford'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_first_name'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Caitlin'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Don_Lamb'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/dislikes'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Weevil_Navaro'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Pirate_Points'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/belongs_to'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/student_council'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Aaron_Echolls'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_trait'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/famous'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Andrea_Sims'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/last_seen_on'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Friday'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/pinata'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/consist_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/steroids'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Clarence_Weidman'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/blackmailing'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Leanne_Mars'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Casey_Gant'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/friend_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Holly_Mills'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Neptune_Grand_Hotel'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/clue_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case2'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/number'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/found_with'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Amy_Polk'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/is_character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Mandy'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Grind_Girl_Magazine'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/clue_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case8'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Wilson'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_first_name'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Wilson'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Catherine_Lenova'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_first_name'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Catherine'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case18'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/classified_as'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/bomb_threat'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Mandy'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/client_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Veronica_Mars'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Weevil_Navarro'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_age'), rdflib.term.Literal('17.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/character_is'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Mrs_Gant'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Alicia_Fennel'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_last_name'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Fennel'))
# (rdflib.term.URIRef("http://UCLA_REU_2020.org/Veronica_Mars/Casey's_Grandmother's_Will"), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/consist_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/money'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/is_character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Vic_Sciaraffa'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Outcasts'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/want'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Candidate_B'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Amy_Polk'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_profession'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Undergraduate'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Veronica_Mars'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/part_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/outcasts'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Trina_Echolls'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/child_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Aaron_Echolls'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Celeste_Kane'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_first_name'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Celeste'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Jack'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/in_club'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/basketball'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Weevil_Navaro'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/bestfriend_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Chardo_Navarro'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Leticia_Navarro'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_first_name'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Leticia'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Sabrina_Fuller'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_last_name'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Fuller'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Lianne_Mars'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_last_name'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Mars'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/is_character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Leanne_Mars'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Debbie_Meyer'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/part_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Moon_Calf_Collective'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/forbidden_barn'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/belongs_to'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Moon_Calf_Collective'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Kelly'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_profession'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Undergraduate'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Veronica_Mars'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/accused'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Duncan_Kane'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Veronica_Mars'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/arrested_for'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case12'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/is_character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Georgia'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/is_character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Andrea_Sims'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Chester'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/belongs_to'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Mandy'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/is_character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Sam_Bloom'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Valedictorian_spot'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/clue_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case17'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Eddie_LaRoche'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_medical_condition'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/mentally_unstable'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Georgia'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_first_name'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Georgia'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Carrie_Bishop'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/source_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Rolling_Stones_music'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/shot_glass'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/belongs_to'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Logan_Echolls'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/diary'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/belongs_to'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Carrie_Bishop'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Bone_Hamilton'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/injured'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Sam_Bloom'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Phone_call'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/consists_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Jake_Kane'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Sarah_Williams'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_last_name'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Williams'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Abel_Koontz'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/arrested_for'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case1'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Weevil_Navarro'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/dislikes'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Logan_Echolls'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Sabrina_Fuller'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/competing_against'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Hamilton_Cho'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/pinata'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/clue_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case5'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Veronica_Mars'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/ex_friend_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Yolanda_Hamilton'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Leticia_Navaro'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/accused_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Credit_Card_Fraud'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Connor_Larkin'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/suspect_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case10'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Tom_Cruz'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_last_name'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Cruz'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/backpack'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/belongs_to'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Lilly_Kane'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Grant_Winters'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_last_name'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Winters'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Veronica_Mars'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/friend_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Cliff_McCormack'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Sabrina_Fuller'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/part_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Kane_Scholarship_Nominees'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/videotapes'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/consist_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/girls_at_bar'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Celeste_Kane'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/hates'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Veronica_Mars'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/tapes'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/clue_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case1'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/is_character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Wilson'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/is_character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Don_Lamb'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Clayton_wifi'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/clue_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case18'))
# (rdflib.term.URIRef("http://UCLA_REU_2020.org/Veronica_Mars/Chester's_collar"), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/clue_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case19'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Luke_Haldeman'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_first_name'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Luke'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Sabrina_Fuller'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/client_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case17'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case4'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/classified_as'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/money_scam'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Celeste_Kane'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/suspect_of'), rdflib.term.URIRef("http://UCLA_REU_2020.org/Veronica_Mars/Lilly_Kane's_death"))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Wallace_Fennel'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/child_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Alicia_Fennel'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Connor_Larkin'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_financial_status'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/upper_class'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Chuck_Rook'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_first_name'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Chuck'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Caz_Truman'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/suspect_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case17'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Drug_problem'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/because_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Bathroom_breaks'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Ransom_video'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/described_as'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/deal'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Dick_Casablancas'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_age'), rdflib.term.Literal('17.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Debbie_Meyer'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_nickname'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Rain'))
# (rdflib.term.URIRef("http://UCLA_REU_2020.org/Veronica_Mars/Chester's_collar"), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/found_with'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Hans'))
# (rdflib.term.URIRef("http://UCLA_REU_2020.org/Veronica_Mars/Casey's_grandmother"), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/died_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/stroke'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Veronica_Mars'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/dislikes'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Vincent_VanLowe'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/sticker'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/clue_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case19'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/09ers'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/want'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Candidate_A'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/is_character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Trina_Echolls'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Karl'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/suspect_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case4'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/is_character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Dime_Bag'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Fake_IDs'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/cost'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/250_dollars'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Veronica_Mars'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/girlfriend_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Troy_Vandegraff'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Marcel'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/likes'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Yolanda_Hamilton'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Lilly_Kane'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_financial_status'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/upper_class'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Perpetrator'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/described_as'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Madison_Sinclair'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/purity_test_score'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/clue_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case8'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Wallace_Fennel'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_profession'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/office_aide'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Expensive_Computers'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/clue_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case4'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Bryca_Hamilton'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_trait'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/genius'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/is_character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Hank_Zigman'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Caitlin_Ford'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_last_name'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Ford'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/big_gun'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/belongs_to'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Ben'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Madison_Sinclair'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/part_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/cheerleaders'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Carrie_Bishop'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/bestfriend_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Susan_Knight'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Bedroom'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/clue_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case10'))
# (rdflib.term.URIRef("http://UCLA_REU_2020.org/Veronica_Mars/Casey's_grandmother"), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/stepmother_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Mrs_Gant'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Jack_Daniels'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/described_as'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Iced_Tea'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Yolanda_Hamilton'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_profession'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/student'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Al_Levine'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_last_name'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Levine'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Perpetrator'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/wants'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/money'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Caz_Truman'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/ex_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Sabrina_Fuller'))
# (rdflib.term.URIRef("http://UCLA_REU_2020.org/Veronica_Mars/Karl's_email"), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_source'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Grant_Winters'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Jim_Cho'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_last_name'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Cho'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Luke_Haldeman'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/friend_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Troy_Vandegraff'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Mandy'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_profession'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/student'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/oxcarbazepine'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_side_effect'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/loss_of_memory'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Vincent_VanLowe'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_trait'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/morally_corrupt'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/breaking_and_entering'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/because_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/spy_pen'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Hans'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_financial_status'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/lower_class'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Mrs._Donaldson'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_last_name'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Donaldson'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Bedroom'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/consists_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/no_money'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Bathroom_breaks'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/clue_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case10'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Perpetrator'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/threatened'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Bone_Hamilton'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Lynn_Echolls'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/died_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/suicide'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Catherina_Lenova'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/source_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/postcard'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/is_character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Katherine_Wills'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Kimmy'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/girlfriend_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Renny_DeMouy'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Yolanda_Hamilton'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/child_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Bone_Hamilton'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Marcel'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/fired_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Bone_Hamilton'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Wallace_Fennel'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/bestfriend_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Veronica_Mars'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Luke_Haldeman'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_financial_status'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/upper_class'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Logan_Echolls'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_financial_status'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/upper_class'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Casey_Gant'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/kidnapped_by'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Mr_Gant'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/is_character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Duncan_Kane'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Wanda_rulez'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/clue_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case6'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case10'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/classified_as'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Stolen_Money'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Dime_Bag'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/not_guilty_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case13'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Logan_Echolls'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/part_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/09ers'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Lilly_Kane'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_age'), rdflib.term.Literal('16.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Sean_Friedrich'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_age'), rdflib.term.Literal('17.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Logan_Echolls'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/ex_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Lilly_Kane'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Susan_Knight'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/in_club'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/speech'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Sabrina_Fuller'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_financial_status'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/upper_class'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Jack_Daniels'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/belongs_to'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Duncan_Kane'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Yolanda_Hamilton'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/ex_friend_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Veronica_Mars'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Stolen_Credit_Cards'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/belongs_to'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Echolls_Family'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Logan_Echolls'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/boyfriend_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Lilly_Kane'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Tory_Vandegraff'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/seen_at'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/USA_Boarder_Diner'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Renny_DeMouy'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_first_name'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Renny'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Jim_Cho'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_profession'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/pizza_shop_owner'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Keith_Mars'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_first_name'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Keith'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Logan_Echolls'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_last_name'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Echolls'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/fertilizer'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/planted_in'), rdflib.term.URIRef("http://UCLA_REU_2020.org/Veronica_Mars/Clayton's_car"))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Tritons'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/clue_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case12'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Alicia_Fennel'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/works_at'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Kane_Software'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Chardo_Navarro'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/part_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/motorcyle_gang'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Veronica_Mars'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/source_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/FakeLetter'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Josh'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_profession'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/manager'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Eddie_LaRoche'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_nickname'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/The_Worm'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Perpetrator'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/described_as'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Grant_Winters'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Mystery_Number'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/source_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Logan_Echolls'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Wanda_Varner'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/runs_for'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Student_Council_President'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Troy_Vandegraff'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_last_name'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Vandegraff'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Andre'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/suspect_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case7'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Vincent_VanLowe'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_first_name'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Vincent'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Casey_Gant'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/part_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Moon_Calf_Collective'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Hank_Zigman'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_profession'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/drug_lord'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Alicia_Fennel'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/mother_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Wallace_Fennel'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Soccer_uniform'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/belongs_to'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Duncan_Kane'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Benjamin_Bloom'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/child_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Sam_Bloom'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/wristband'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/clue_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case11'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Yolanda_Hamilton'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_last_name'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Hamilton'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Lizzy_Manning'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/protects'), rdflib.term.URIRef("http://UCLA_REU_2020.org/Veronica_Mars/Meg_Manning's_Purity"))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Mr._Gant'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/married_to'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Mrs_Gant'))
# (rdflib.term.URIRef("http://UCLA_REU_2020.org/Veronica_Mars/Sarah's_Journal"), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/belongs_to'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Sarah_Williams'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Josh'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/works_at'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/E-Tones'))
# (rdflib.term.URIRef("http://UCLA_REU_2020.org/Veronica_Mars/Chester's_collar"), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/belongs_to'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Chester'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Leticia_Navarro'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_financial_status'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/lower_class'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/traditional_job'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/because_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/weekend_killings'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Gabe'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/works_at'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Evermore_Guitars'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Club_Leadership'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/consist_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/News_Club_Leader'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Andre'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_trait'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/bad_temper'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/bet'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/threatened'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Neptune_High'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Perpetrator'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/described_as'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Kimmy'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Dime_Bag'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/seen_at'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/club'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Bone_Hamilton'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_enemy'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Dime_Bag'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/is_character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Jim_Cho'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Veronica_Mars'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/source_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Expensive_Computers'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Credit_Card_Purchases'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/consists_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Neptune_Grand_Hotel'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Mr_Gant'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_last_name'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Gant'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/website'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/consists_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/countdown'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Veronica_Mars'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/source_of'), rdflib.term.URIRef("http://UCLA_REU_2020.org/Veronica_Mars/Karl's_email"))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Madison_Sinclair'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/threatened'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Wanda_Varner'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Perpetrator'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_access_to'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/ballot_instructions'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Duncan_Kane'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/sibling_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Lilly_Kane'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Abel_Koonz'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/suspect_of'), rdflib.term.URIRef("http://UCLA_REU_2020.org/Veronica_Mars/Lilly_Kane's_death"))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Veronica_Mars'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/doubts'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Drug_problem'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Luke_Haldeman'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/source_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/pinata'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Veronica_Mars'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_age'), rdflib.term.Literal('17.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Darcy'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_profession'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/student'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Lilly_Kane'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_affair_with'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Weevil_Navarro'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Diamond_Pendant'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/source_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Keith_Mars'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Vic_Sciaraffa'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_first_name'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Vic'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Carrie_Bishop'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_trait'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/gossiper'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Cole'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/boyfriend_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Meg_Manning'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Mandy'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/described_as'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/lower_class'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/purity_test_score'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/described_as'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Social'))
# ...
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Perpetrator'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/described_as'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Chuck_Rook'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/is_character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Caz_Truman'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case7'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/classified_as'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/missing_person'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Rebecca_James'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_last_name'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/James'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Grant_Winters'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_access_to'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/tech_domain'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Car'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/belongs_to'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Debra_Villareal'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Leanne_Mars'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/married_to'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Keith_Mars'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Carrie_Bishop'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/source_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/diary'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/is_character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Aaron_Echolls'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Hans'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_profession'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/student'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Keith_Mars'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/friend_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Cliff_McCormack'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Perpetrator'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/described_as'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Troy_Vandegraff'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Meg_Manning'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/part_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/News_Club'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case5'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/classified_as'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/drug_trafficking'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/perpetrator'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_access_to'), rdflib.term.URIRef("http://UCLA_REU_2020.org/Veronica_Mars/Meg's_Password"))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Logan_Echolls'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/ex_friend_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Veronica_Mars'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/is_character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Al_Levine'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Lilly_Kane'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_last_name'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Kane'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Julia_Smith'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_first_name'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Julia'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/character_is'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Dick_Casablancas'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Meg_Manning'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/victim_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case8'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Carrie_Bishop'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_last_name'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Bishop'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Ghetto_Brew'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/clue_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case10'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/is_character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Andre'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Duncan_Kane'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/described_as'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Candidate_A'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Veronica_Mars'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/doubts'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Carrie_Bishop'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Perpetrator'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/described_as'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Bryce_Hamilton'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Perpetrator'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/described_as'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Rick'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Renny_DeMouy'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_access_to'), rdflib.term.URIRef("http://UCLA_REU_2020.org/Veronica_Mars/Meg's_Password"))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Credit_Card_Fraud'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/consists_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Stolen_Credit_Cards'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Mrs._Donaldson'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/works_at'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Neptune_High'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/number'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/clue_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case11'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Ghetto_Brew'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/belongs_to'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Sean_Friedrich'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Benjamin_Bloom'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_first_name'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Benjamin'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Duncan_Kane'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/friend_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Troy_Vandegraff'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Chester'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/described_as'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/dog'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Bone_Hamilton'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_enemy'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Sam_Bloom'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Perpetrator'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/described_as'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Julia_Smith'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Susan_Knight'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/described_as'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/pregnant'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/picture'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/clue_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case16'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/number'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/belongs_to'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Vic_Sciaraffa'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Wanda_Varner'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/dislikes'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Madison_Sinclair'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/wristband'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/seen_at'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Evermore_Guitars'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Jim_Cho'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_financial_status'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/lower_class'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Pizza_tip'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/because_of'), rdflib.term.URIRef("http://UCLA_REU_2020.org/Veronica_Mars/Duncan's_Lie"))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Meg_Manning'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_profession'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/student'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/texts'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/clue_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case14'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Kimmy'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/jealous_of'), rdflib.term.URIRef("http://UCLA_REU_2020.org/Veronica_Mars/Meg_Manning's_Purity"))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Weevil_Navarro'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/ex_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Lilly_Kane'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Celeste_Kane'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/dislikes'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Keith_Mars'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Katherine_Wills'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/victim_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case11'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Perpetrator'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_trait'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/genius'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/hard_drives'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/belongs_to'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Grant_Winters'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Holly_Mills'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_first_name'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Holly'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/is_character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Jake_Kane'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Justin_Smith'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_profession'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/student'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/is_character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Luke_Haldeman'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Andrea_Sims'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_last_name'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Sims'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Pete'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/suspect_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case18'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/is_character'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Pete'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Perpetrator'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/described_as'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Hans'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Hamilton_Cho'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_profession'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/pizza_delivery_worker'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Amy_Polk'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/victim_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case11'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Perpetrator'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/described_as'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Sean_Friedrich'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Aaron_Echolls'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_trait'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/uncontrollable_anger'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Steve'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/described_as'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/catalouha_leopard_dog'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Lizzy_Manning'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/sibling_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Meg_Manning'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Van_Clemmons'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_last_name'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Clemmons'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Gabe'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/suspect_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case11'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Gabe'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_access_to'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Evermore_Guitars'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Meg_Manning'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/friend_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Kimmy'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Wallace_Fennel'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/part_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/outcasts'))

# %%
# save graph
g.serialize(destination="VM_KG.ttl", format='turtle')

# %%
'''
    Create the RDF triples with Reification and Episode Time
'''
import rdflib
import xlrd
import pandas
from rdflib import URIRef, Literal, BNode,Namespace

data = { # similar format for how you made your pandas data fram
    "subject": [],
    "predicate": [],
    "object" : [],
    "time": [], # time context for each triple
    "discovered_at": []
}
SS_name = "VMars Triples.xlsx"
wb = xlrd.open_workbook(SS_name)

for l in range(wb.nsheets):
    sheet = wb.sheet_by_index(l)
    for i in range(1, sheet.nrows): # skip the first header line
        s = sheet.cell_value(i, 0)
        p = sheet.cell_value(i, 1)
        o = sheet.cell_value(i, 2)
        t = sheet.cell_value(i, 3)
        
        if not t: # If there is no time in col 3 then assign episode time
            t = l
        
        if not s or not p or not o: # if any are empty then no triple
            continue
            
        data["subject"].append(s)
        data["predicate"].append(p)
        data["object"].append(o)
        
        if t != l: # if triple time and episode time are distinct
            data['discovered_at'].append(l * 10)
            data['time'].append(t)
        else:
            data["time"].append(l * 10)
            data["discovered_at"].append(None)

    
data_processed = {
    'subject':[],'predicate':[],'object': [], "time": [], "discovered_at": []
}
ugly_token = {
    ' ': '_',
    '"': '',
}

# replace all ugly tokens and copy to new data structure
for x in data.keys(): # x is subj, obj, pred, time
    for item in data[x]:
        if type(item) != str:
            data_processed[x].append(item)
            continue
        new_token=item
        new_token = new_token.strip()
        for k in ugly_token:
            new_token=new_token.replace(k, ugly_token[k]) 
        data_processed[x].append(new_token)            

n = Namespace("http://UCLA_REU_2020.org/Veronica_Mars/")

'''
 (x, meet, y) -->
     (meet1, hasSrc, x)
     (meet1, hasDst, y)
     (meet1, hasType, meet)
     (meet1, hasTime, 0950)
     (meet1, hasLoc, Neptune High School)
'''
g = rdflib.Graph()
pred_counts = {} # Dictionary mapping each predicate to the number of times they have been used
for i in range(len(data['subject'])):
    s = data_processed['subject'][i]
    p = data_processed['predicate'][i]
    o = data_processed['object'][i]
    t = data_processed['time'][i]
    d = data_processed['discovered_at'][i]
    
    if type(o)==float or type(o)==int:
        o_node=Literal(o)
    else:
        o_node=n[o]
    
    if p in pred_counts:
        pred_counts[p] += 1
    else:
        pred_counts[p] = 1
    
    g.add(( n[p+str(pred_counts[p])], n['hasSrc'], n[s] )) # (meet1, hasSrc, x)
    g.add(( n[p+str(pred_counts[p])], n['hasDst'], o_node )) # (meet1, hasDst, y)
    g.add(( n[p+str(pred_counts[p])], n['hasType'], n[p] )) # (meet1, hasType, meet)
    g.add(( n[p+str(pred_counts[p])], n['hasTime'], Literal(t) )) # (meet1, hasTime, 0950)
    
    if d is not None:
        g.add(( n[p+str(pred_counts[p])], n['discovered_at'], Literal(d) )) # (meet1, discovered_at, 1050)

print(len(list(g.triples((None, None, None)))))

#check g
for s, p, o in g:
    #print((s, p, o))
    pass

# Example of how to find all friend instances in new knowledge graph
# Note that WE HAVENT REFINED THE GRAPH
# Do a function which is the opposite of stripURI
print(pred_counts['clue_of'])
all_friends = list(g.subjects(predicate=URIRef('http://UCLA_REU_2020.org/Veronica_Mars/hasType'), object=URIRef('http://UCLA_REU_2020.org/Veronica_Mars/clue_of')))
for f_inst in all_friends:
    f1 = stripURI(next(g.objects(subject=f_inst, predicate=URIRef('http://UCLA_REU_2020.org/Veronica_Mars/hasSrc')), None))
    f2 = stripURI(next(g.objects(subject=f_inst, predicate=URIRef('http://UCLA_REU_2020.org/Veronica_Mars/hasDst')), None))
    
    print("{} is clue of {}".format(f1, f2))
# Out:
# 4668
# 78
# wristband is clue of Case11
# Meg_Manning's_Purity is clue of Case8
# Lilly's_Secret is clue of Case1
# Karl's_email is clue of Case4
# postcard is clue of Case15
# fertilizer is clue of Case18
# Ransom_video is clue of Case16
# diary is clue of Case14
# texts is clue of Case14
# Sun_Tea is clue of Case10
# Clayton_wifi is clue of Case18
# Dog_man is clue of Case19
# pinata is clue of Case5
# Rolling_Stones_music is clue of Case14
# big_gun is clue of Case18
# Sarah's_DNA_Test is clue of Case7
# sticker is clue of Case19
# Bedroom is clue of Case10
# Credit_Card is clue of Veronica's_stalker
# house_key is clue of Case14
# Jack_Daniels is clue of Case10
# Candidate_order is clue of Case6
# Speeding_Ticket is clue of Case1
# Car is clue of Case17
# Diamond_Pendant is clue of Case2
# Wanda_rulez is clue of Case6
# purity_test_score is clue of Case8
# Exploding_tennis_balls is clue of Case18
# number is clue of Case11
# Holly_Mills is clue of Case9
# videotapes is clue of Case11
# Abel_Koonz's_confession is clue of Case1
# Credit_Card_Purchases is clue of Case2
# 250_dollars is clue of Case12
# Steve is clue of Case15
# backpack is clue of Case1
# asphyxiation is clue of Case11
# picture is clue of Case16
# shot_glass is clue of Case1
# shoes is clue of Case1
# Crime_Photographs is clue of Case1
# black,_silk_sheets is clue of Case14
# John_Smith's_Death is clue of Case3
# bet is clue of Case16
# Abel_Koonz's_bloody_clothing is clue of Case1
# Soccer_uniform is clue of Case1
# Tritons is clue of Case12
# white_sneakers is clue of innocence_of_Abel_Koonz
# Ghetto_Brew is clue of Case10
# Selling_Porsche is clue of Case9
# Valedictorian_spot is clue of Case17
# Pizza_tip is clue of Case10
# Expensive_Computers is clue of Case4
# White_van is clue of Case19
# Grind_Girl_Magazine is clue of Case8
# Moon_Calf_Collective is clue of Case9
# Sarah's_Sexual_Assault is clue of Case7
# Lost_dog_notices is clue of Case19
# spy_pen is clue of Case1
# Sarah's_Journal is clue of Case7
# Phone_call is clue of Case1
# Chester's_collar is clue of Case19
# Mystery_Number is clue of Case2
# FakeLetter is clue of Case3
# Duncan's_Lie is clue of Case10
# Neptune_Grand_Hotel is clue of Case2
# tracking_device is clue of Case5
# tapes is clue of Case1
# Sarah_ran_away_from_home is clue of Case7
# Bathroom_breaks is clue of Case10
# white_sneakers is clue of Case1
# Drug_problem is clue of Case10
# Witness_Protection_Program is clue of Case15
# Carrie's_Grade is clue of Case14
# SK is clue of Case14
# KillemAll is clue of Case18
# Polly_article is clue of Case16
# Fire_Drills is clue of Case18

# %% [markdown]
# ## Utils

# %%
'''
    Utils
'''
def stripURI(x):
    return x.split("/")[-1]

def replaceUgly(df, ugly_tokens):
    pass

# %% [markdown]
# ## visualization

# %%
'''
    Display all the clues of case1
'''

import matplotlib.pyplot as plt
import networkx as nx

def stripURI(x):
    return x.split("/")[-1]

a = URIRef('http://UCLA_REU_2020.org/Veronica_Mars/clue_of')
b = URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case1')

# %matplotlib qt
#%matplotlib inline
plt.figure(figsize=(20,20))

edgelabels={}
G = nx.DiGraph()
#plt.clf()
for subj in g.subjects(predicate=a, object=b):
    v1 = stripURI(subj)
    v2 = stripURI(b)
    G.add_edge(v1, v2)
    edgelabels[(v1,v2)] = stripURI(a)

#print(edge_labels)

pos = nx.spring_layout(G,k=0.15,iterations=20, scale=3)
nx.draw_networkx(G, pos=pos,font_size=8,node_color='pink')
nx.draw_networkx_edge_labels(G, pos=pos, edge_labels=edgelabels, font_size=7)

plt.show()

print(list(g.subjects(predicate=a, object=b)))
# Out:
# [rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/shot_glass'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/tapes'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Crime_Photographs'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/white_sneakers'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Phone_call'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/spy_pen'), rdflib.term.URIRef("http://UCLA_REU_2020.org/Veronica_Mars/Lilly's_Secret"), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/backpack'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/shoes'), rdflib.term.URIRef("http://UCLA_REU_2020.org/Veronica_Mars/Abel_Koonz's_bloody_clothing"), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Soccer_uniform'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Speeding_Ticket'), rdflib.term.URIRef("http://UCLA_REU_2020.org/Veronica_Mars/Abel_Koonz's_confession")]
# C:\Users\masha\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:563: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# C:\Users\masha\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:660: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes

# %%
'''
    Example SPARQL Query 1
    Output the financial status of every character
'''

qres = g.query(
    """PREFIX foaf: <http://UCLA_REU_2020.org/Veronica_Mars/>
       SELECT ?bname
       WHERE {
          # ?aname foaf:has_financial_status ?bname.
       }""")

for row in qres:
    print(row)
# Out:
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/upper_class'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/upper_class'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/upper_class'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/lower_class'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/upper_class'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/upper_class'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/upper_class'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/lower_class'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/upper_class'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/upper_class'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/upper_class'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/upper_class'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/lower_class'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/upper_class'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/upper_class'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/upper_class'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/lower_class'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/lower_class'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/lower_class'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/upper_class'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/upper_class'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/lower_class'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/lower_class'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/lower_class'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/lower_class'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/upper_class'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/lower_class'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/lower_class'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/upper_class'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/upper_class'),)

# %%
'''
    Example SPARQL Query 2
    Output the first name of every character
'''

qres = g.query(
    """PREFIX foaf: <http://UCLA_REU_2020.org/Veronica_Mars/>
       SELECT ?bname
       WHERE {
          # ?aname foaf:has_first_name ?bname.
       }""")

for row in qres:
    print(row)
# Out:
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Vincent'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Ben'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Van'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Clarence'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Vic'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Josh'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Wallace'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Andrea'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Luke'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Sarah'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Carrie'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Nathan'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Richie'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Mandy'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Norris'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Katherine'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Yolanda'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Amy'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Leanne'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Jack'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Casey'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Bone'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Caitlin'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Eli'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Abel'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Gabe'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Kelly'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Lizzy'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Eddie'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Jerry'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Don'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Jimmy'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Marcel'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Debra'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Pete'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Meg'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Leticia'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Wanda'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Sean'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Duncan'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Connor'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Chardo'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Madison'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Troy'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Benjamin'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Darcy'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/John'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Aaron'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Renny'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Trina'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Susan'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Logan'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Celeste'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Tom'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Georgia'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Julia'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Wilson'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Jim'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Bryce'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Justin'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Sabrina'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Hans'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Lynn'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Al'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Alicia'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Kimmy'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Chuck'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Rebecca'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Cliff'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Debbie'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Catherine'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Grant'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Caz'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Dick'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Rick'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Lilly'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Jake'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Hamilton'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Veronica'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Keith'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Sam'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Hank'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Holly'),)

# %%
'''
    Example SPARQL Query 3
    Output all triple of which Weevil_Navarro is the subject
'''

qres = g.query(
    """PREFIX foaf: <http://UCLA_REU_2020.org/Veronica_Mars/>
       SELECT ?predicate ?object
       WHERE {
           foaf:Weevil_Navarro ?predicate ?object.
       }""")

for row in qres:
    print(row)
# Out:
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_trait'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/juvenile_delinquent'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/dislikes'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Logan_Echolls'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/arrested_for'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case2'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/client_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case10'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_nickname'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Weevil'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/suspect_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case2'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_profession'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/student'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_alibi'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case2'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_affair_with'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Lilly_Kane'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_first_name'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Eli'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/arrested_for'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/breaking_and_entering'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/ex_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Lilly_Kane'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/part_of'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/motorcycle_gang'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_last_name'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Navarro'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_age'), rdflib.term.Literal('17.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/has_financial_status'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/lower_class'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/wants'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/money'))

# %%
'''
    Example SPARQL Query 4
    Output all clues
'''
qres = g.query(
    """PREFIX foaf: <http://UCLA_REU_2020.org/Veronica_Mars/>
       SELECT ?subject ?object
       WHERE {
           # ?subject foaf:clue_of ?object.
       }""")

for row in qres:
    print(row)
# Out:
# (rdflib.term.URIRef("http://UCLA_REU_2020.org/Veronica_Mars/Karl's_email"), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case4'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/bet'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case16'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Tritons'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case12'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Witness_Protection_Program'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case15'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Soccer_uniform'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case1'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/white_sneakers'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/innocence_of_Abel_Koonz'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/videotapes'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case11'))
# (rdflib.term.URIRef("http://UCLA_REU_2020.org/Veronica_Mars/Sarah's_DNA_Test"), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case7'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/house_key'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case14'))
# (rdflib.term.URIRef("http://UCLA_REU_2020.org/Veronica_Mars/Abel_Koonz's_confession"), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case1'))
# (rdflib.term.URIRef("http://UCLA_REU_2020.org/Veronica_Mars/Sarah's_Sexual_Assault"), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case7'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/shoes'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case1'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/250_dollars'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case12'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Exploding_tennis_balls'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case18'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Polly_article'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case16'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Ransom_video'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case16'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Neptune_Grand_Hotel'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case2'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/sticker'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case19'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Selling_Porsche'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case9'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Grind_Girl_Magazine'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case8'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Mystery_Number'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case2'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/wristband'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case11'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/KillemAll'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case18'))
# (rdflib.term.URIRef("http://UCLA_REU_2020.org/Veronica_Mars/John_Smith's_Death"), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case3'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Sun_Tea'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case10'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Ghetto_Brew'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case10'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/postcard'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case15'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Candidate_order'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case6'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/spy_pen'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case1'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/purity_test_score'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case8'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Sarah_ran_away_from_home'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case7'))
# (rdflib.term.URIRef("http://UCLA_REU_2020.org/Veronica_Mars/Lilly's_Secret"), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case1'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Lost_dog_notices'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case19'))
# (rdflib.term.URIRef("http://UCLA_REU_2020.org/Veronica_Mars/Sarah's_Journal"), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case7'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/fertilizer'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case18'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Moon_Calf_Collective'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case9'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Fire_Drills'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case18'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Expensive_Computers'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case4'))
# (rdflib.term.URIRef("http://UCLA_REU_2020.org/Veronica_Mars/Abel_Koonz's_bloody_clothing"), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case1'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Steve'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case15'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Bedroom'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case10'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/white_sneakers'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case1'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/number'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case11'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/SK'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case14'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/shot_glass'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case1'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Phone_call'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case1'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Diamond_Pendant'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case2'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Pizza_tip'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case10'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Valedictorian_spot'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case17'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/picture'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case16'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/tracking_device'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case5'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Dog_man'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case19'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Speeding_Ticket'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case1'))
# (rdflib.term.URIRef("http://UCLA_REU_2020.org/Veronica_Mars/Meg_Manning's_Purity"), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case8'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Credit_Card'), rdflib.term.URIRef("http://UCLA_REU_2020.org/Veronica_Mars/Veronica's_stalker"))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Crime_Photographs'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case1'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/asphyxiation'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case11'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/texts'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case14'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Bathroom_breaks'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case10'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/diary'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case14'))
# (rdflib.term.URIRef("http://UCLA_REU_2020.org/Veronica_Mars/Carrie's_Grade"), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case14'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Car'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case17'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Drug_problem'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case10'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/backpack'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case1'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Credit_Card_Purchases'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case2'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Jack_Daniels'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case10'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/White_van'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case19'))
# (rdflib.term.URIRef("http://UCLA_REU_2020.org/Veronica_Mars/Duncan's_Lie"), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case10'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Wanda_rulez'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case6'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/FakeLetter'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case3'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/pinata'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case5'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/black,_silk_sheets'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case14'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Holly_Mills'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case9'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/tapes'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case1'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/big_gun'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case18'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Clayton_wifi'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case18'))
# (rdflib.term.URIRef("http://UCLA_REU_2020.org/Veronica_Mars/Chester's_collar"), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case19'))
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Rolling_Stones_music'), rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Case14'))

# %%
'''
    Example SPARQL Query 5
    Output all clues of case 1
'''
qres = g.query(
    """PREFIX foaf: <http://UCLA_REU_2020.org/Veronica_Mars/>
       SELECT ?subject 
       WHERE {
                 # ?subject foaf:clue_of foaf:Case1.
         
       }""")

for row in qres:
    print(row)
# Out:
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/spy_pen'),)
# (rdflib.term.URIRef("http://UCLA_REU_2020.org/Veronica_Mars/Lilly's_Secret"),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/white_sneakers'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Speeding_Ticket'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/tapes'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Soccer_uniform'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Crime_Photographs'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/shot_glass'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/backpack'),)
# (rdflib.term.URIRef("http://UCLA_REU_2020.org/Veronica_Mars/Abel_Koonz's_bloody_clothing"),)
# (rdflib.term.URIRef("http://UCLA_REU_2020.org/Veronica_Mars/Abel_Koonz's_confession"),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Phone_call'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/shoes'),)

# %%
'''
    Example SPARQL Query 6
    Output all characters who are considered part of the 'outcasts' in the show.
'''
qres = g.query(
    """PREFIX foaf: <http://UCLA_REU_2020.org/Veronica_Mars/>
       SELECT ?subject 
       WHERE {
                 # ?subject foaf:part_of foaf:outcasts.              
                      
         }""")

for row in qres:
    print(row)
# Out:
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Veronica_Mars'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Wanda_Varner'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Wallace_Fennel'),)
# (rdflib.term.URIRef('http://UCLA_REU_2020.org/Veronica_Mars/Wilson'),)
